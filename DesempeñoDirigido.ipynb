# %%
from ImageNet100ValDataset import *

# %% [markdown]
# El objetivo es forzar los gallos n01514859

# %%
NOISY_DIR = "FGSM_targeted_n01883070"
SELECTED_DIR = "val.X"
noisy_dataset = ImageNet100ValDataset(NOISY_DIR, transform=transform)
selected_dataset = ImageNet100ValDataset(SELECTED_DIR, transform=transform)
metricas = {}

# %%
from Modelos.ResNet50 import evaluate_resnet50
acc_t1_res50, acc_t5_res50 = evaluate_resnet50(SELECTED_DIR)
metricas['ResNet50'] = (acc_t1_res50, acc_t5_res50)
print(f"Top 1 accuracy ResNet50: {acc_t1_res50}")
print(f"Top 5 accuracy ResNet50: {acc_t5_res50}")
# Out:
# Top 1 accuracy ResNet50: 0.8864
# Top 5 accuracy ResNet50: 0.9776

# %%
noisy_acc_t1_res50, noisy_acc_t5_res50 = evaluate_resnet50(NOISY_DIR)
metricas['ResNet50 PGD'] = (noisy_acc_t1_res50, noisy_acc_t5_res50)
print(f"Top 1 PGD accuracy ResNet50: {noisy_acc_t1_res50}")
print(f"Top 5 PGD accuracy ResNet50: {noisy_acc_t5_res50}")
# Out:
# Top 1 PGD accuracy ResNet50: 0.7308
# Top 5 PGD accuracy ResNet50: 0.9146

# %%
from Modelos.ResNet34 import evaluate_resnet34
acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(SELECTED_DIR)
metricas['ResNet34'] = (acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 accuracy ResNet34: {acc_t1_res34}")
print(f"Top 5 accuracy ResNet34: {noisy_acc_t5_res34}")
# Out:
# Top 1 accuracy ResNet34: 0.8408
# Top 5 accuracy ResNet34: 0.965

# %%
noisy_acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(NOISY_DIR)
metricas['ResNet34 PGD'] = (noisy_acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 PGD accuracy ResNet34: {noisy_acc_t1_res34}")
print(f"Top 5 PGD accuracy ResNet34: {noisy_acc_t5_res34}")
# Out:
# Top 1 PGD accuracy ResNet34: 0.424
# Top 5 PGD accuracy ResNet34: 0.7066

# %%
import matplotlib.pyplot as plt
import numpy as np

modelos = list(metricas.keys())
acc_t1 = [metricas[m][0] for m in modelos]
acc_t5 = [metricas[m][1] for m in modelos]

x = np.arange(len(modelos))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, acc_t1, width, label='Top-1 Accuracy')
plt.bar(x + width/2, acc_t5, width, label='Top-5 Accuracy')

plt.xticks(x, modelos, rotation=20)
plt.ylabel('Accuracy')
plt.title('Ataque FGSM dirigido')
plt.legend()
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("graficos/Ataques FGSM dirigido.png", dpi=300, transparent=True, bbox_inches="tight")
plt.show()

# %%
NOISY_DIR = "RFGSM_dirigido_target_106"
noisy_dataset = ImageNet100ValDataset(NOISY_DIR, transform=transform)

# %%
noisy_acc_t1_res50, noisy_acc_t5_res50 = evaluate_resnet50(NOISY_DIR)
metricas['ResNet50 PGD'] = (noisy_acc_t1_res50, noisy_acc_t5_res50)
print(f"Top 1 PGD accuracy ResNet50: {noisy_acc_t1_res50}")
print(f"Top 5 PGD accuracy ResNet50: {noisy_acc_t5_res50}")
# Out:
# Top 1 PGD accuracy ResNet50: 0.7076
# Top 5 PGD accuracy ResNet50: 0.902

# %%
noisy_acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(NOISY_DIR)
metricas['ResNet34 PGD'] = (noisy_acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 PGD accuracy ResNet34: {noisy_acc_t1_res34}")
print(f"Top 5 PGD accuracy ResNet34: {noisy_acc_t5_res34}")
# Out:
# Top 1 PGD accuracy ResNet34: 0.3504
# Top 5 PGD accuracy ResNet34: 0.639

# %%
modelos = list(metricas.keys())
acc_t1 = [metricas[m][0] for m in modelos]
acc_t5 = [metricas[m][1] for m in modelos]

x = np.arange(len(modelos))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, acc_t1, width, label='Top-1 Accuracy')
plt.bar(x + width/2, acc_t5, width, label='Top-5 Accuracy')

plt.xticks(x, modelos, rotation=20)
plt.ylabel('Accuracy')
plt.title('Ataque RFGSM dirigido')
plt.legend()
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("graficos/Ataques RFGSM dirigido.png", dpi=300, transparent=True, bbox_inches="tight")
plt.show()

# %%
NOISY_DIR = "val_pgd_untargeted_015"
noisy_dataset = ImageNet100ValDataset(NOISY_DIR, transform=transform)

# %%
noisy_acc_t1_res50, noisy_acc_t5_res50 = evaluate_resnet50(NOISY_DIR)
metricas['ResNet50 PGD'] = (noisy_acc_t1_res50, noisy_acc_t5_res50)
print(f"Top 1 PGD accuracy ResNet50: {noisy_acc_t1_res50}")
print(f"Top 5 PGD accuracy ResNet50: {noisy_acc_t5_res50}")
# Out:
# Top 1 PGD accuracy ResNet50: 0.806
# Top 5 PGD accuracy ResNet50: 0.9488

# %%
noisy_acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(NOISY_DIR)
metricas['ResNet34 PGD'] = (noisy_acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 FGSM accuracy ResNet34: {noisy_acc_t1_res34}")
print(f"Top 5 FGSM accuracy ResNet34: {noisy_acc_t5_res34}")
# Out:
# Top 1 FGSM accuracy ResNet34: 0.6988
# Top 5 FGSM accuracy ResNet34: 0.8804

# %%
modelos = list(metricas.keys())
acc_t1 = [metricas[m][0] for m in modelos]
acc_t5 = [metricas[m][1] for m in modelos]

x = np.arange(len(modelos))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, acc_t1, width, label='Top-1 Accuracy')
plt.bar(x + width/2, acc_t5, width, label='Top-5 Accuracy')

plt.xticks(x, modelos, rotation=20)
plt.ylabel('Accuracy')
plt.title('Ataque PGD dirigido')
plt.legend()
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("graficos/Ataques PGD dirigido.png", dpi=300, transparent=True, bbox_inches="tight")
plt.show()
