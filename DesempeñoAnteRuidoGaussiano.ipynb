# %%
from ImageNet100ValDataset import *

# %%
noisy_dataset = ImageNet100ValDataset("val_noisy.X", transform=transform)
metricas = {}

# %%
from Modelos.ResNet50 import evaluate_resnet50
acc_t1_res50, acc_t5_res50 = evaluate_resnet50(noisy_dataset)
metricas['ResNet50'] = (acc_t1_res50, acc_t5_res50)
print(f"Top 1 accuracy ResNet50: {acc_t1_res50}")
print(f"Top 5 accuracy ResNet50: {acc_t5_res50}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 from Modelos.ResNet50 import evaluate_resnet50
# ----> 2 acc_t1_res50, acc_t5_res50 = evaluate_resnet50(noisy_dataset)
#       3 metricas['ResNet50'] = (acc_t1_res50, acc_t5_res50)
#       4 print(f"Top 1 accuracy ResNet50: {acc_t1_res50}")
#
# File c:\Users\Benjamin\OneDrive - Universidad de Chile\Escritorio\Tareas progra\Inteligencia compuacional\Defensa-adversaria-en-redes-neuronales-con-ImagenNet\Modelos\ResNet50.py:16, in evaluate_resnet50(VAL_DIR)
#      13 preprocess = transform
#      15 # Dataset
# ---> 16 val_dataset = ImageNet100ValDataset(VAL_DIR, transform=preprocess)
#      17 val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
#      19 imagenet_classes = weights.meta["categories"]
#
# File c:\Users\Benjamin\OneDrive - Universidad de Chile\Escritorio\Tareas progra\Inteligencia compuacional\Defensa-adversaria-en-redes-neuronales-con-ImagenNet\ImageNet100ValDataset.py:11, in ImageNet100ValDataset.__init__(self, root_dir, transform)
#       9 self.root_dir = root_dir
#      10 self.transform = transform
# ---> 11 self.class_to_idx = {c: i for i, c in enumerate(sorted(os.listdir(root_dir)))}
#      12 self.samples = [
#      13     (os.path.join(root_dir, c, f), self.class_to_idx[c])
#      14     for c in self.class_to_idx
#      15     for f in os.listdir(os.path.join(root_dir, c))
#      16     if f.lower().endswith(('.jpg', '.jpeg', '.png', '.jpeg'))
#      17 ]
#
# TypeError: listdir: path should be string, bytes, os.PathLike or None, not ImageNet100ValDataset
