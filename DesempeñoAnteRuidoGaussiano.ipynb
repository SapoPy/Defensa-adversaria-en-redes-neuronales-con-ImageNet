# %%
from ImageNet100ValDataset import *

# %%
NOISY_DIR = "val_noisy"
SELECTED_DIR = "val.X"
noisy_dataset = ImageNet100ValDataset(NOISY_DIR, transform=transform)
selected_dataset = ImageNet100ValDataset(SELECTED_DIR, transform=transform)
metricas = {}

# %%
from Modelos.ResNet50 import evaluate_resnet50
acc_t1_res50, acc_t5_res50 = evaluate_resnet50(SELECTED_DIR)
metricas['ResNet50'] = (acc_t1_res50, acc_t5_res50)
print(f"Top 1 accuracy ResNet50: {acc_t1_res50}")
print(f"Top 5 accuracy ResNet50: {acc_t5_res50}")
# Out:
# Top 1 accuracy ResNet50: 0.8864
# Top 5 accuracy ResNet50: 0.9776

# %%
noisy_acc_t1_res50, noisy_acc_t5_res50 = evaluate_resnet50(NOISY_DIR)
metricas['ResNet50 noisy'] = (noisy_acc_t1_res50, noisy_acc_t5_res50)
print(f"Top 1 noisy accuracy ResNet50: {noisy_acc_t1_res50}")
print(f"Top 5 noisy accuracy ResNet50: {noisy_acc_t5_res50}")
# Out:
# Top 1 noisy accuracy ResNet50: 0.8626
# Top 5 noisy accuracy ResNet50: 0.9722

# %%
from Modelos.ResNet34 import evaluate_resnet34
acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(SELECTED_DIR)
metricas['ResNet34'] = (acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 accuracy ResNet34: {acc_t1_res34}")
print(f"Top 5 accuracy ResNet3: {noisy_acc_t5_res34}")
# Out:
# Top 1 accuracy ResNet34: 0.8408
# Top 5 accuracy ResNet3: 0.965

# %%
noisy_acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(NOISY_DIR)
metricas['ResNet34 noisy'] = (noisy_acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 noisy accuracy ResNet34: {noisy_acc_t1_res34}")
print(f"Top 5 noisy accuracy ResNet34: {noisy_acc_t5_res34}")
# Out:
# Top 1 noisy accuracy ResNet34: 0.8186
# Top 5 noisy accuracy ResNet34: 0.9624

# %%
import matplotlib.pyplot as plt
import numpy as np

modelos = list(metricas.keys())
acc_t1 = [metricas[m][0] for m in modelos]
acc_t5 = [metricas[m][1] for m in modelos]

x = np.arange(len(modelos))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, acc_t1, width, label='Top-1 Accuracy')
plt.bar(x + width/2, acc_t5, width, label='Top-5 Accuracy')

plt.xticks(x, modelos, rotation=20)
plt.ylabel('Accuracy')
plt.title('Ataques Gaussianos: std = 0.05')
plt.legend()
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("graficos/Ataques Gaussianos std = 0.05.png", dpi=300, transparent=True, bbox_inches="tight")
plt.show()

# %%
NOISY_DIR = "val_noisy_01"
noisy_dataset = ImageNet100ValDataset(NOISY_DIR, transform=transform)

noisy_acc_t1_res50, noisy_acc_t5_res50 = evaluate_resnet50(NOISY_DIR)
metricas['ResNet50 noisy'] = (noisy_acc_t1_res50, noisy_acc_t5_res50)
print(f"Top 1 noisy accuracy ResNet50: {noisy_acc_t1_res50}")
print(f"Top 5 noisy accuracy ResNet50: {noisy_acc_t5_res50}")
# Out:
# Top 1 noisy accuracy ResNet50: 0.8342
# Top 5 noisy accuracy ResNet50: 0.9658

# %%
noisy_acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(NOISY_DIR)
metricas['ResNet34 noisy'] = (noisy_acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 noisy accuracy ResNet34: {noisy_acc_t1_res34}")
print(f"Top 5 noisy accuracy ResNet34: {noisy_acc_t5_res34}")
# Out:
# Top 1 noisy accuracy ResNet34: 0.787
# Top 5 noisy accuracy ResNet34: 0.947

# %%
modelos = list(metricas.keys())
acc_t1 = [metricas[m][0] for m in modelos]
acc_t5 = [metricas[m][1] for m in modelos]

x = np.arange(len(modelos))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, acc_t1, width, label='Top-1 Accuracy')
plt.bar(x + width/2, acc_t5, width, label='Top-5 Accuracy')

plt.xticks(x, modelos, rotation=20)
plt.ylabel('Accuracy')
plt.title('Ataques Gaussianos: std = 0.1')
plt.legend()
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("graficos/Ataques Gaussianos std = 0.1.png", dpi=300, transparent=True, bbox_inches="tight")
plt.show()

# %%
NOISY_DIR = "val_noisy_015"
noisy_dataset = ImageNet100ValDataset(NOISY_DIR, transform=transform)

noisy_acc_t1_res50, noisy_acc_t5_res50 = evaluate_resnet50(NOISY_DIR)
metricas['ResNet50 noisy'] = (noisy_acc_t1_res50, noisy_acc_t5_res50)
print(f"Top 1 noisy accuracy ResNet50: {noisy_acc_t1_res50}")
print(f"Top 5 noisy accuracy ResNet50: {noisy_acc_t5_res50}")
# Out:
# Top 1 noisy accuracy ResNet50: 0.8152
# Top 5 noisy accuracy ResNet50: 0.9538

# %%
noisy_acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(NOISY_DIR)
metricas['ResNet34 noisy'] = (noisy_acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 noisy accuracy ResNet34: {noisy_acc_t1_res34}") 
print(f"Top 5 noisy accuracy ResNet34: {noisy_acc_t5_res34}")
# Out:
# Top 1 noisy accuracy ResNet34: 0.7388
# Top 5 noisy accuracy ResNet34: 0.9204

# %%
modelos = list(metricas.keys())
acc_t1 = [metricas[m][0] for m in modelos]
acc_t5 = [metricas[m][1] for m in modelos]

x = np.arange(len(modelos))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, acc_t1, width, label='Top-1 Accuracy')
plt.bar(x + width/2, acc_t5, width, label='Top-5 Accuracy')

plt.xticks(x, modelos, rotation=20)
plt.ylabel('Accuracy')
plt.title('Ataques Gaussianos: std = 0.15')
plt.legend()
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("graficos/Ataques Gaussianos std = 0.15.png", dpi=300, transparent=True, bbox_inches="tight")
plt.show()
