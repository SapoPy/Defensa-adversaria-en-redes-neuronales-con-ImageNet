# %%
from ImageNet100ValDataset import *

# %% [markdown]
# El objetivo es forzar los gallos n01514859

# %%
NOISY_DIR = "val_pgd_targeted"
SELECTED_DIR = "3 clases"
noisy_dataset = ImageNet100ValDataset(NOISY_DIR, transform=transform)
selected_dataset = ImageNet100ValDataset(SELECTED_DIR, transform=transform)
metricas = {}

# %%
from Modelos.ResNet50 import evaluate_resnet50
acc_t1_res50, acc_t5_res50 = evaluate_resnet50(SELECTED_DIR)
metricas['ResNet50 selected'] = (acc_t1_res50, acc_t5_res50)
print(f"Top 1 accuracy ResNet50 (selected): {acc_t1_res50}")
print(f"Top 5 accuracy ResNet50 (selected): {acc_t5_res50}")
# Out:
# Top 1 accuracy ResNet50 (selected): 0.9466666666666667
# Top 5 accuracy ResNet50 (selected): 0.98

# %%
noisy_acc_t1_res50, noisy_acc_t5_res50 = evaluate_resnet50(NOISY_DIR)
metricas['ResNet50 PGD'] = (noisy_acc_t1_res50, noisy_acc_t5_res50)
print(f"Top 1 PGD accuracy ResNet50: {noisy_acc_t1_res50}")
print(f"Top 5 PGD accuracy ResNet50: {noisy_acc_t5_res50}")
# Out:
# Top 1 PGD accuracy ResNet50: 0.92
# Top 5 PGD accuracy ResNet50: 0.9666666666666667

# %%
from Modelos.ResNet34 import evaluate_resnet34
acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(SELECTED_DIR)
metricas['ResNet34 selected'] = (acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 accuracy ResNet34 (selected): {acc_t1_res34}")
print(f"Top 5 accuracy ResNet34 (selected): {noisy_acc_t5_res34}")
# Out:
# Top 1 accuracy ResNet34 (selected): 0.9066666666666666
# Top 5 accuracy ResNet34 (selected): 0.9733333333333334

# %%
noisy_acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(NOISY_DIR)
metricas['ResNet34 PGD'] = (noisy_acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 PGD accuracy ResNet34: {noisy_acc_t1_res34}")
print(f"Top 5 PGD accuracy ResNet34: {noisy_acc_t5_res34}")
# Out:
# Top 1 PGD accuracy ResNet34: 0.8733333333333333
# Top 5 PGD accuracy ResNet34: 0.9666666666666667

# %%
import matplotlib.pyplot as plt
import numpy as np

modelos = list(metricas.keys())
acc_t1 = [metricas[m][0] for m in modelos]
acc_t5 = [metricas[m][1] for m in modelos]

x = np.arange(len(modelos))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, acc_t1, width, label='Top-1 Accuracy')
plt.bar(x + width/2, acc_t5, width, label='Top-5 Accuracy')

plt.xticks(x, modelos, rotation=20)
plt.ylabel('Accuracy')
plt.title('Ataque PGD: ε = 0.05 ')
plt.legend()
plt.ylim(0.65, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
NOISY_DIR = "val_pgd_targeted_01"
noisy_dataset = ImageNet100ValDataset(NOISY_DIR, transform=transform)

# %%
noisy_acc_t1_res50, noisy_acc_t5_res50 = evaluate_resnet50(NOISY_DIR)
metricas['ResNet50 PGD'] = (noisy_acc_t1_res50, noisy_acc_t5_res50)
print(f"Top 1 PGD accuracy ResNet50: {noisy_acc_t1_res50}")
print(f"Top 5 PGD accuracy ResNet50: {noisy_acc_t5_res50}")
# Out:
# Top 1 PGD accuracy ResNet50: 0.9066666666666666
# Top 5 PGD accuracy ResNet50: 0.9666666666666667

# %%
noisy_acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(NOISY_DIR)
metricas['ResNet34 PGD'] = (noisy_acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 PGD accuracy ResNet34: {noisy_acc_t1_res34}")
print(f"Top 5 PGD accuracy ResNet34: {noisy_acc_t5_res34}")
# Out:
# Top 1 PGD accuracy ResNet34: 0.8333333333333334
# Top 5 PGD accuracy ResNet34: 0.94

# %%
modelos = list(metricas.keys())
acc_t1 = [metricas[m][0] for m in modelos]
acc_t5 = [metricas[m][1] for m in modelos]

x = np.arange(len(modelos))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, acc_t1, width, label='Top-1 Accuracy')
plt.bar(x + width/2, acc_t5, width, label='Top-5 Accuracy')

plt.xticks(x, modelos, rotation=20)
plt.ylabel('Accuracy')
plt.title('Ataque PGD: ε = 0.1')
plt.legend()
plt.ylim(0.65, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
NOISY_DIR = "val_pgd_targeted_015"
noisy_dataset = ImageNet100ValDataset(NOISY_DIR, transform=transform)

# %%
noisy_acc_t1_res50, noisy_acc_t5_res50 = evaluate_resnet50(NOISY_DIR)
metricas['ResNet50 PGD'] = (noisy_acc_t1_res50, noisy_acc_t5_res50)
print(f"Top 1 PGD accuracy ResNet50: {noisy_acc_t1_res50}")
print(f"Top 5 PGD accuracy ResNet50: {noisy_acc_t5_res50}")
# Out:
# Top 1 PGD accuracy ResNet50: 0.8866666666666667
# Top 5 PGD accuracy ResNet50: 0.9533333333333334

# %%
noisy_acc_t1_res34, noisy_acc_t5_res34 = evaluate_resnet34(NOISY_DIR)
metricas['ResNet34 FGSM'] = (noisy_acc_t1_res34, noisy_acc_t5_res34)
print(f"Top 1 FGSM accuracy ResNet34: {noisy_acc_t1_res34}")
print(f"Top 5 FGSM accuracy ResNet34: {noisy_acc_t5_res34}")
# Out:
# Top 1 FGSM accuracy ResNet34: 0.7866666666666666
# Top 5 FGSM accuracy ResNet34: 0.9066666666666666

# %%
modelos = list(metricas.keys())
acc_t1 = [metricas[m][0] for m in modelos]
acc_t5 = [metricas[m][1] for m in modelos]

x = np.arange(len(modelos))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, acc_t1, width, label='Top-1 Accuracy')
plt.bar(x + width/2, acc_t5, width, label='Top-5 Accuracy')

plt.xticks(x, modelos, rotation=20)
plt.ylabel('Accuracy')
plt.title('Ataque PGD: ε = 0.15')
plt.legend()
plt.ylim(0.65, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
